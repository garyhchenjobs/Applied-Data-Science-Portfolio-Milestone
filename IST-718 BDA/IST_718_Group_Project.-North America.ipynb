# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load emissions data
url = 'https://raw.githubusercontent.com/garyhchenjobs/IST718-Group_Final/main/GLEAM_LivestockEmissions.csv'
emissions = pd.read_csv(url)
print(emissions.head(5))
# Out:
#    Region Animal species  Production system   Commodity  \
# 0  Global         Cattle         Aggregated  Aggregated
# 1  Global         Cattle         Aggregated        Milk
# 2  Global         Cattle         Aggregated        Meat
# 3  Global         Cattle  Grassland systems  Aggregated
# 4  Global         Cattle  Grassland systems        Milk
#
#    Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 0                                        160.3             2.916310e+10
# 1                                         86.7             1.888089e+10
# 2                                        295.4             1.028222e+10
# 3                                        206.3             1.033817e+10
# 4                                         95.0             6.940654e+09
#
#    Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 0                   4.670000e+12                   9.450000e+11
# 1                   1.640000e+12                   2.760000e+11
# 2                   3.040000e+12                   6.690000e+11
# 3                   2.130000e+12                   5.630000e+11
# 4                   6.590000e+11                   9.286140e+10
#
#    Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  ...  \
# 0                   2.650000e+12                   1.080000e+12  ...
# 1                   9.680000e+11                   3.940000e+11  ...
# 2                   1.680000e+12                   6.870000e+11  ...
# 3                   1.050000e+12                   5.170000e+11  ...
# 4                   3.710000e+11                   1.950000e+11  ...
#
#    Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 0                                     1.740000e+11
# 1                                     7.166208e+10
# 2                                     1.020000e+11
# 3                                     5.253660e+10
# 4                                     2.156126e+10
#
#    Feed: applied & deposited manure, N2O (kg CO2e)  \
# 0                                     7.420000e+11
# 1                                     2.540000e+11
# 2                                     4.880000e+11
# 3                                     4.270000e+11
# 4                                     1.590000e+11
#
#    LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 0                    4.687954e+10                           3.870000e+11
# 1                    1.497421e+10                                    NaN
# 2                    3.190534e+10                           3.870000e+11
# 3                    8.194330e+09                           3.870000e+11
# 4                    2.412100e+09                                    NaN
#
#    Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 0                         2.510000e+12                      1.390000e+11
# 1                         8.860000e+11                      8.200906e+10
# 2                         1.620000e+12                      5.744310e+10
# 3                         9.970000e+11                      5.605552e+10
# 4                         3.370000e+11                      3.444428e+10
#
#    Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 0                      1.650000e+11                  4.215542e+10
# 1                      6.813278e+10                  2.993485e+10
# 2                      9.678019e+10                  1.222057e+10
# 3                      3.798508e+10                  1.417326e+10
# 4                      1.473188e+10                  1.078605e+10
#
#    Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)
# 0                    1.585653e+10             9.955932e+10
# 1                    3.252889e+09             8.929544e+10
# 2                    1.260364e+10             1.026388e+10
# 3                    4.303272e+09             3.773092e+10
# 4                    9.998435e+08             3.462338e+10
#
# [5 rows x 22 columns]

# %%
emissions_south_asia = emissions.loc[(emissions['Region'] == 'South Asia') & 
                         (emissions['Commodity'] == 'Aggregated') &
                         (emissions['Production system'] == 'Aggregated')]
emissions_south_asia.head()
# Out:
#          Region Animal species Production system   Commodity  \
# 424  South Asia         Cattle        Aggregated  Aggregated
# 435  South Asia      Buffaloes        Aggregated  Aggregated
# 444  South Asia          Sheep        Aggregated  Aggregated
# 453  South Asia          Goats        Aggregated  Aggregated
# 462  South Asia           Pigs        Aggregated  Aggregated
#
#      Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 424                                        221.1             3.312079e+09
# 435                                        164.7             3.517246e+09
# 444                                        270.3             1.470987e+08
# 453                                        159.9             4.711411e+08
# 462                                         75.9             1.231999e+08
#
#      Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 424                   7.320000e+11                   1.110000e+11
# 435                   5.790000e+11                   9.993832e+10
# 444                   3.976482e+10                   4.846419e+09
# 453                   7.533304e+10                   1.167652e+10
# 462                   9.352089e+09                   2.648732e+09
#
#      Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  ...  \
# 424                   4.680000e+11                   1.530000e+11  ...
# 435                   3.560000e+11                   1.240000e+11  ...
# 444                   2.738814e+10                   7.530263e+09  ...
# 453                   5.139999e+10                   1.225652e+10  ...
# 462                   4.693916e+09                   2.009440e+09  ...
#
#      Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 424                                     4.273179e+10
# 435                                     4.162243e+10
# 444                                     2.218088e+09
# 453                                     4.554711e+09
# 462                                     8.749754e+08
#
#      Feed: applied & deposited manure, N2O (kg CO2e)  \
# 424                                     7.155194e+10
# 435                                     5.631178e+10
# 444                                     5.046311e+09
# 453                                     6.597382e+09
# 462                                     3.603544e+08
#
#      LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 424                    1.492877e+09                                    NaN
# 435                    1.878365e+09                                    NaN
# 444                    9.349844e+06                                    NaN
# 453                    2.203821e+06                                    NaN
# 462                    3.104926e+08                                    NaN
#
#      Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 424                         4.570000e+11                      1.079124e+10
# 435                         3.490000e+11                      6.927192e+09
# 444                         2.652341e+10                      8.647334e+08
# 453                         4.819384e+10                      3.206147e+09
# 462                         3.263805e+08                      3.393300e+09
#
#      Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 424                      3.867203e+10                  3.618877e+09
# 435                      2.557253e+10                  3.885815e+09
# 444                      2.658643e+08                  1.924309e+08
# 453                      1.104432e+09                  2.279583e+08
# 462                      7.741106e+08                  5.696733e+07
#
#      Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)
# 424                     404346467.0             1.269176e+10
# 435                     153931144.0             3.001399e+10
# 444                     131016899.0             1.698969e+08
# 453                     669977361.0             3.114634e+08
# 462                       7850124.0             1.842217e+08
#
# [5 rows x 22 columns]

# %%
# restrict to North America
emissions = emissions.loc[emissions['Region'] == 'North America']

# %%
crop = pd.read_csv('https://raw.githubusercontent.com/garyhchenjobs/IST718-Group_Final/main/crops_north_america.csv')
crop.head()
# Out:
#    Unnamed: 0                 Area     Item         Element  Year Unit  Value
# 0       29614  Antigua and Barbuda  Bananas  Area harvested  1966   ha    3.0
# 1       29615  Antigua and Barbuda  Bananas  Area harvested  1967   ha    6.0
# 2       29616  Antigua and Barbuda  Bananas  Area harvested  1968   ha    8.0
# 3       29617  Antigua and Barbuda  Bananas  Area harvested  1969   ha   10.0
# 4       29618  Antigua and Barbuda  Bananas  Area harvested  1970   ha   10.0

# %%
live = pd.read_csv('https://raw.githubusercontent.com/garyhchenjobs/IST718-Group_Final/main/live1.csv')
live.head()
# Out:
#           Area   Item Element  Year  Unit      Value
# 0  Afghanistan  Asses  Stocks  1961  Head  1300000.0
# 1  Afghanistan  Asses  Stocks  1962  Head   851850.0
# 2  Afghanistan  Asses  Stocks  1963  Head  1001112.0
# 3  Afghanistan  Asses  Stocks  1964  Head  1150000.0
# 4  Afghanistan  Asses  Stocks  1965  Head  1300000.0

# %%
emissions = pd.read_csv('https://raw.githubusercontent.com/garyhchenjobs/IST718-Group_Final/main/GLEAM_LivestockEmissions.csv')
emissions.head()
# Out:
#    Region Animal species  Production system   Commodity  \
# 0  Global         Cattle         Aggregated  Aggregated
# 1  Global         Cattle         Aggregated        Milk
# 2  Global         Cattle         Aggregated        Meat
# 3  Global         Cattle  Grassland systems  Aggregated
# 4  Global         Cattle  Grassland systems        Milk
#
#    Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 0                                        160.3             2.916310e+10
# 1                                         86.7             1.888089e+10
# 2                                        295.4             1.028222e+10
# 3                                        206.3             1.033817e+10
# 4                                         95.0             6.940654e+09
#
#    Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 0                   4.670000e+12                   9.450000e+11
# 1                   1.640000e+12                   2.760000e+11
# 2                   3.040000e+12                   6.690000e+11
# 3                   2.130000e+12                   5.630000e+11
# 4                   6.590000e+11                   9.286140e+10
#
#    Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  ...  \
# 0                   2.650000e+12                   1.080000e+12  ...
# 1                   9.680000e+11                   3.940000e+11  ...
# 2                   1.680000e+12                   6.870000e+11  ...
# 3                   1.050000e+12                   5.170000e+11  ...
# 4                   3.710000e+11                   1.950000e+11  ...
#
#    Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 0                                     1.740000e+11
# 1                                     7.166208e+10
# 2                                     1.020000e+11
# 3                                     5.253660e+10
# 4                                     2.156126e+10
#
#    Feed: applied & deposited manure, N2O (kg CO2e)  \
# 0                                     7.420000e+11
# 1                                     2.540000e+11
# 2                                     4.880000e+11
# 3                                     4.270000e+11
# 4                                     1.590000e+11
#
#    LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 0                    4.687954e+10                           3.870000e+11
# 1                    1.497421e+10                                    NaN
# 2                    3.190534e+10                           3.870000e+11
# 3                    8.194330e+09                           3.870000e+11
# 4                    2.412100e+09                                    NaN
#
#    Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 0                         2.510000e+12                      1.390000e+11
# 1                         8.860000e+11                      8.200906e+10
# 2                         1.620000e+12                      5.744310e+10
# 3                         9.970000e+11                      5.605552e+10
# 4                         3.370000e+11                      3.444428e+10
#
#    Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 0                      1.650000e+11                  4.215542e+10
# 1                      6.813278e+10                  2.993485e+10
# 2                      9.678019e+10                  1.222057e+10
# 3                      3.798508e+10                  1.417326e+10
# 4                      1.473188e+10                  1.078605e+10
#
#    Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)
# 0                    1.585653e+10             9.955932e+10
# 1                    3.252889e+09             8.929544e+10
# 2                    1.260364e+10             1.026388e+10
# 3                    4.303272e+09             3.773092e+10
# 4                    9.998435e+08             3.462338e+10
#
# [5 rows x 22 columns]

# %%
# for pigs set commodity to aggregated instead of meat

# %%
# restrict to North America
# keep only production system = aggregated and commodity = aggregated
emissions = emissions.loc[(emissions['Region'] == 'North America') & 
                         (emissions['Commodity'] == 'Aggregated') &
                         (emissions['Production system'] == 'Aggregated')]
emissions.head()
# Out:
#             Region Animal species Production system   Commodity  \
# 265  North America         Cattle        Aggregated  Aggregated
# 276  North America      Buffaloes        Aggregated  Aggregated
# 285  North America          Sheep        Aggregated  Aggregated
# 294  North America          Goats        Aggregated  Aggregated
# 303  North America           Pigs        Aggregated  Aggregated
#
#      Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 265                                         94.6             4.946003e+09
# 276                                         60.1             7.024894e+06
# 285                                        217.2             9.801088e+06
# 294                                         88.2             1.134177e+07
# 303                                         36.5             1.742059e+09
#
#      Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 265                   4.680000e+11                   7.051503e+10
# 276                   4.221187e+08                   1.079537e+08
# 285                   2.128659e+09                   2.356789e+08
# 294                   9.999067e+08                   1.651756e+08
# 303                   6.362182e+10                   2.655649e+10
#
#      Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  ...  \
# 265                   2.930000e+11                   1.040000e+11  ...
# 276                   2.687895e+08                   4.537546e+07  ...
# 285                   1.205789e+09                   6.871912e+08  ...
# 294                   6.252210e+08                   2.095101e+08  ...
# 303                   2.661064e+10                   1.045469e+10  ...
#
#      Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 265                                     1.664071e+10
# 276                                     1.846504e+07
# 285                                     1.219854e+08
# 294                                     7.609850e+07
# 303                                     5.787965e+09
#
#      Feed: applied & deposited manure, N2O (kg CO2e)  \
# 265                                     6.327627e+10
# 276                                     1.615659e+06
# 285                                     5.091959e+08
# 294                                     1.055958e+08
# 303                                     2.166712e+09
#
#      LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 265                     155347196.0                                    NaN
# 276                        772513.0                                    NaN
# 285                        261765.0                                    NaN
# 294                         65461.0                                    NaN
# 303                     175433250.0                                    NaN
#
#      Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 265                         2.380000e+11                      5.522328e+10
# 276                         2.481596e+08                      2.062994e+07
# 285                         1.161617e+09                      4.417170e+07
# 294                         5.938516e+08                      3.136936e+07
# 303                         2.547485e+09                      2.406315e+10
#
#      Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 265                      2.453400e+10                  1.119346e+10
# 276                      2.529477e+07                  6.210765e+06
# 285                      5.600990e+07                  3.740802e+07
# 294                      2.781578e+07                  1.833978e+07
# 303                      2.500017e+09                  3.508714e+09
#
#      Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)
# 265                    4.342067e+09             3.123173e+10
# 276                    2.800580e+06             5.968451e+07
# 285                    7.224516e+06             3.621570e+07
# 294                    2.844452e+07             2.505232e+07
# 303                    1.018953e+09             6.654234e+09
#
# [5 rows x 22 columns]

# %%
# animals in north america by CO2 emissions
emissions.sort_values(by=["Total CO2 emissions (kg CO2e)"], ascending=False)
# Out:
#             Region Animal species Production system   Commodity  \
# 265  North America         Cattle        Aggregated  Aggregated
# 307  North America        Chicken        Aggregated  Aggregated
# 303  North America           Pigs        Aggregated  Aggregated
# 285  North America          Sheep        Aggregated  Aggregated
# 294  North America          Goats        Aggregated  Aggregated
# 276  North America      Buffaloes        Aggregated  Aggregated
#
#      Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 265                                         94.6             4.946003e+09
# 307                                         20.2             3.367069e+09
# 303                                         36.5             1.742059e+09
# 285                                        217.2             9.801088e+06
# 294                                         88.2             1.134177e+07
# 276                                         60.1             7.024894e+06
#
#      Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 265                   4.680000e+11                   7.051503e+10
# 307                   6.804370e+10                   4.325686e+10
# 303                   6.362182e+10                   2.655649e+10
# 285                   2.128659e+09                   2.356789e+08
# 294                   9.999067e+08                   1.651756e+08
# 276                   4.221187e+08                   1.079537e+08
#
#      Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  ...  \
# 265                   2.930000e+11                   1.040000e+11  ...
# 307                   3.520174e+09                   2.126667e+10  ...
# 303                   2.661064e+10                   1.045469e+10  ...
# 285                   1.205789e+09                   6.871912e+08  ...
# 294                   6.252210e+08                   2.095101e+08  ...
# 276                   2.687895e+08                   4.537546e+07  ...
#
#      Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 265                                     1.664071e+10
# 307                                     7.995893e+09
# 303                                     5.787965e+09
# 285                                     1.219854e+08
# 294                                     7.609850e+07
# 276                                     1.846504e+07
#
#      Feed: applied & deposited manure, N2O (kg CO2e)  \
# 265                                     6.327627e+10
# 307                                     8.858449e+09
# 303                                     2.166712e+09
# 285                                     5.091959e+08
# 294                                     1.055958e+08
# 276                                     1.615659e+06
#
#      LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 265                     155347196.0                                    NaN
# 307                     329732398.0                                    NaN
# 303                     175433250.0                                    NaN
# 285                        261765.0                                    NaN
# 294                         65461.0                                    NaN
# 276                        772513.0                                    NaN
#
#      Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 265                         2.380000e+11                      5.522328e+10
# 307                                  NaN                      3.520174e+09
# 303                         2.547485e+09                      2.406315e+10
# 285                         1.161617e+09                      4.417170e+07
# 294                         5.938516e+08                      3.136936e+07
# 276                         2.481596e+08                      2.062994e+07
#
#      Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 265                      2.453400e+10                  1.119346e+10
# 307                      4.412324e+09                  9.602130e+09
# 303                      2.500017e+09                  3.508714e+09
# 285                      5.600990e+07                  3.740802e+07
# 294                      2.781578e+07                  1.833978e+07
# 276                      2.529477e+07                  6.210765e+06
#
#      Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)
# 265                    4.342067e+09             3.123173e+10
# 307                    1.878925e+09             8.740349e+09
# 303                    1.018953e+09             6.654234e+09
# 285                    7.224516e+06             3.621570e+07
# 294                    2.844452e+07             2.505232e+07
# 276                    2.800580e+06             5.968451e+07
#
# [6 rows x 22 columns]

# %%
# restrict livestock to North America
live_north = live.loc[live['Area'] == 'Northern America']
live_north.head()
# Out:
#                     Area   Item Element  Year  Unit    Value
# 103661  Northern America  Asses  Stocks  1961  Head  15000.0
# 103662  Northern America  Asses  Stocks  1962  Head  15000.0
# 103663  Northern America  Asses  Stocks  1963  Head  15000.0
# 103664  Northern America  Asses  Stocks  1964  Head  16000.0
# 103665  Northern America  Asses  Stocks  1965  Head  16000.0

# %%
# edit live_north Area to merge with emissions
live_north['Area'] = live_north['Area'].replace(['Northern America'], 'North America')
live_north['Item'] = live_north['Item'].replace(['Chickens'], 'Chicken')
# Out:
# <ipython-input-12-d41c04df6faf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   live_north['Area'] = live_north['Area'].replace(['Northern America'], 'North America')
# <ipython-input-12-d41c04df6faf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   live_north['Item'] = live_north['Item'].replace(['Chickens'], 'Chicken')

# %%
live_north.rename(columns={'Area': 'Region', 'Item': 'Animal species'}, inplace=True)
live_north.head()
# Out:
# <ipython-input-13-7ffa6417d0e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   live_north.rename(columns={'Area': 'Region', 'Item': 'Animal species'}, inplace=True)
#                Region Animal species Element  Year  Unit    Value
# 103661  North America          Asses  Stocks  1961  Head  15000.0
# 103662  North America          Asses  Stocks  1962  Head  15000.0
# 103663  North America          Asses  Stocks  1963  Head  15000.0
# 103664  North America          Asses  Stocks  1964  Head  16000.0
# 103665  North America          Asses  Stocks  1965  Head  16000.0

# %%
# kg protein per head x value --> use average value
# cattle 20-40 kg per head
# chicken 80 - 100g per chicken
# sheep 27-31 kg protein per head
# goats 5-7 kg protein per head
# pigs
# join emissions and livestock dataframes
live_emissions = pd.merge(live_north, emissions, on=['Region', 'Animal species'], how = 'inner')
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Chicken", live_emissions["Value"]*1000*.165, live_emissions["Value"])
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Cattle", live_emissions["Value"]*52, live_emissions["Value"])
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Pigs", live_emissions["Value"]*12, live_emissions["Value"])
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Buffaloes", live_emissions["Value"]*112, live_emissions["Value"])
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Sheep", live_emissions["Value"]*20, live_emissions["Value"])
live_emissions["Value"] = np.where(live_emissions["Animal species"] == "Goats", live_emissions["Value"]*6, live_emissions["Value"])
live_emissions['Final_GHG'] = live_emissions['Value'] * live_emissions['Emission Intensity (kg CO2e per kg protein)']

# kg protein per head x value
# cattle 52 kg per head
# chicken 0.165kg per chicken
# sheep 20 kg protein per head
# buffalo 112 kg per head
# goats 5-7 kg protein per head
# pigs 12 kg protein per head

# live_emissions.loc[live_es_asia_sum['Animal species'] == 'Cattle'].head()
live_emissions['Final_GHG'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      5.332294e+11
# 1      5.475238e+11
# 2      5.692124e+11
# 3      5.882520e+11
# 4      5.958619e+11
#            ...
# 295    2.654227e+10
# 296    2.642846e+10
# 297    2.647407e+10
# 298    2.631508e+10
# 299    2.604576e+10
# Name: Final_GHG, Length: 300, dtype: float64>

# %%
display(live_emissions.head())
# Out:
#           Region Animal species Element  Year  Unit         Value  \
# 0  North America         Cattle  Stocks  1961  Head  5.636675e+09
# 1  North America         Cattle  Stocks  1962  Head  5.787778e+09
# 2  North America         Cattle  Stocks  1963  Head  6.017045e+09
# 3  North America         Cattle  Stocks  1964  Head  6.218309e+09
# 4  North America         Cattle  Stocks  1965  Head  6.298751e+09
#
#   Production system   Commodity  Emission Intensity (kg CO2e per kg protein)  \
# 0        Aggregated  Aggregated                                         94.6
# 1        Aggregated  Aggregated                                         94.6
# 2        Aggregated  Aggregated                                         94.6
# 3        Aggregated  Aggregated                                         94.6
# 4        Aggregated  Aggregated                                         94.6
#
#    Production (kg protein)  ...  \
# 0             4.946003e+09  ...
# 1             4.946003e+09  ...
# 2             4.946003e+09  ...
# 3             4.946003e+09  ...
# 4             4.946003e+09  ...
#
#    Feed: applied & deposited manure, N2O (kg CO2e)  \
# 0                                     6.327627e+10
# 1                                     6.327627e+10
# 2                                     6.327627e+10
# 3                                     6.327627e+10
# 4                                     6.327627e+10
#
#    LUC: soy & palm, CO2 (kg CO2e)  LUC: pasture expansion, CO2 (kg CO2e)  \
# 0                     155347196.0                                    NaN
# 1                     155347196.0                                    NaN
# 2                     155347196.0                                    NaN
# 3                     155347196.0                                    NaN
# 4                     155347196.0                                    NaN
#
#    Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 0                         2.380000e+11                      5.522328e+10
# 1                         2.380000e+11                      5.522328e+10
# 2                         2.380000e+11                      5.522328e+10
# 3                         2.380000e+11                      5.522328e+10
# 4                         2.380000e+11                      5.522328e+10
#
#    Manure management, N2O (kg CO2e)  Direct energy, CO2 (kg CO2e)  \
# 0                      2.453400e+10                  1.119346e+10
# 1                      2.453400e+10                  1.119346e+10
# 2                      2.453400e+10                  1.119346e+10
# 3                      2.453400e+10                  1.119346e+10
# 4                      2.453400e+10                  1.119346e+10
#
#    Indirect energy, CO2 (kg CO2e)  Postfarm, CO2 (kg CO2e)     Final_GHG
# 0                    4.342067e+09             3.123173e+10  5.332294e+11
# 1                    4.342067e+09             3.123173e+10  5.475238e+11
# 2                    4.342067e+09             3.123173e+10  5.692124e+11
# 3                    4.342067e+09             3.123173e+10  5.882520e+11
# 4                    4.342067e+09             3.123173e+10  5.958619e+11
#
# [5 rows x 27 columns]

# %%
# join emissions and livestock dataframes
#live_emissions = pd.merge(live_north, emissions, on=['Region', 'Animal species'], how = 'inner')
#live_emissions.loc[live_emissions['Animal species'] == 'Cattle'].head()

# %%
live_emissions.shape
# Out:
# (300, 27)

# %%
cattle_emissions = live_emissions.loc[live_emissions['Animal species'] == 'Cattle']
cattle_emissions.plot(x='Year', y='Value', kind='scatter')
cattle_emissions.plot(x='Year', y='Total GHG emissions (kg CO2e)', kind='scatter')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Year', ylabel='Total GHG emissions (kg CO2e)'>

# %%
plt.hist(live_emissions['Total GHG emissions (kg CO2e)'], bins=10)
plt.title('Histogram of Emissions')
plt.xlabel('kg CO2e')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(live_emissions['Value'], bins=100)
plt.title('Histogram of Production')
plt.xlabel('kg Production')
plt.ylabel('Frequency')
plt.show()

# %%
Sheep_emissions = live_emissions.loc[live_emissions['Animal species'] == 'Sheep']
Sheep_emissions.plot(x='Year', y='Value', kind='scatter')
Sheep_emissions.plot(x='Year', y='Total GHG emissions (kg CO2e)', kind='scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Total GHG emissions (kg CO2e)'>

# %%
Chicken_emissions = live_emissions.loc[live_emissions['Animal species'] == 'Chicken']
Chicken_emissions.plot(x='Year', y='Value', kind='scatter')
Chicken_emissions.plot(x='Year', y='Total GHG emissions (kg CO2e)', kind='scatter')
# Out:
# <Axes: xlabel='Year', ylabel='Total GHG emissions (kg CO2e)'>

# %%
live_emissions['Animal species'].unique()
# Out:
# array(['Cattle', 'Chicken', 'Goats', 'Pigs', 'Sheep'], dtype=object)

# %%
live_emissions[live_emissions['Animal species']=='Chicken']
# Out:
#             Region Animal species Element  Year       Unit         Value  \
# 60   North America        Chicken  Stocks  1961  1000 Head  1.354676e+08
# 61   North America        Chicken  Stocks  1962  1000 Head  1.397694e+08
# 62   North America        Chicken  Stocks  1963  1000 Head  1.398738e+08
# 63   North America        Chicken  Stocks  1964  1000 Head  1.424930e+08
# 64   North America        Chicken  Stocks  1965  1000 Head  1.492055e+08
# 65   North America        Chicken  Stocks  1966  1000 Head  1.529408e+08
# 66   North America        Chicken  Stocks  1967  1000 Head  1.585120e+08
# 67   North America        Chicken  Stocks  1968  1000 Head  1.593913e+08
# 68   North America        Chicken  Stocks  1969  1000 Head  1.649132e+08
# 69   North America        Chicken  Stocks  1970  1000 Head  1.676388e+08
# 70   North America        Chicken  Stocks  1971  1000 Head  1.670868e+08
# 71   North America        Chicken  Stocks  1972  1000 Head  1.693296e+08
# 72   North America        Chicken  Stocks  1973  1000 Head  1.646563e+08
# 73   North America        Chicken  Stocks  1974  1000 Head  1.645619e+08
# 74   North America        Chicken  Stocks  1975  1000 Head  1.598908e+08
# 75   North America        Chicken  Stocks  1976  1000 Head  1.671993e+08
# 76   North America        Chicken  Stocks  1977  1000 Head  1.722717e+08
# 65         Aggregated  Aggregated
# 66         Aggregated  Aggregated
# 67         Aggregated  Aggregated
# 68         Aggregated  Aggregated
# 69         Aggregated  Aggregated
# 70         Aggregated  Aggregated
# 71         Aggregated  Aggregated
# 72         Aggregated  Aggregated
# 73         Aggregated  Aggregated
# 74         Aggregated  Aggregated
# 75         Aggregated  Aggregated
# 76         Aggregated  Aggregated
# 77         Aggregated  Aggregated
# 78         Aggregated  Aggregated
# 79         Aggregated  Aggregated
# 80         Aggregated  Aggregated
# 81         Aggregated  Aggregated
# 82         Aggregated  Aggregated
# 83         Aggregated  Aggregated
# 84         Aggregated  Aggregated
# 85         Aggregated  Aggregated
# 86         Aggregated  Aggregated
# 87         Aggregated  Aggregated
# 88         Aggregated  Aggregated
# 89         Aggregated  Aggregated
# 90         Aggregated  Aggregated
# 91         Aggregated  Aggregated
# 92         Aggregated  Aggregated
# 93         Aggregated  Aggregated
# 94         Aggregated  Aggregated
# 95         Aggregated  Aggregated
# 96         Aggregated  Aggregated
# 97         Aggregated  Aggregated
# 98         Aggregated  Aggregated
# 99         Aggregated  Aggregated
# 100        Aggregated  Aggregated
# 101        Aggregated  Aggregated
# 102        Aggregated  Aggregated
# 103        Aggregated  Aggregated
# 104        Aggregated  Aggregated
# 105        Aggregated  Aggregated
# 106        Aggregated  Aggregated
# 107        Aggregated  Aggregated
# 108        Aggregated  Aggregated
# 109        Aggregated  Aggregated
# 110        Aggregated  Aggregated
# 111        Aggregated  Aggregated
# 112        Aggregated  Aggregated
# 113        Aggregated  Aggregated
# 114        Aggregated  Aggregated
# 115        Aggregated  Aggregated
# 116        Aggregated  Aggregated
# 117        Aggregated  Aggregated
# 118        Aggregated  Aggregated
# 119        Aggregated  Aggregated
#
#      Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 60                                          20.2             3.367069e+09
# 61                                          20.2             3.367069e+09
# 62                                          20.2             3.367069e+09
# 63                                          20.2             3.367069e+09
# 64                                          20.2             3.367069e+09
# 65                                          20.2             3.367069e+09
# 66                                          20.2             3.367069e+09
# 67                                          20.2             3.367069e+09
# 68                                          20.2             3.367069e+09
# 69                                          20.2             3.367069e+09
# 70                                          20.2             3.367069e+09
# 71                                          20.2             3.367069e+09
# 72                                          20.2             3.367069e+09
# 73                                          20.2             3.367069e+09
# 74                                          20.2             3.367069e+09
# 75                                          20.2             3.367069e+09
# 76                                          20.2             3.367069e+09
# 77                                          20.2             3.367069e+09
# 78                                          20.2             3.367069e+09
# 79                                          20.2             3.367069e+09
# 80                                          20.2             3.367069e+09
# 81                                          20.2             3.367069e+09
# 82                                          20.2             3.367069e+09
# 83                                          20.2             3.367069e+09
# 84                                          20.2             3.367069e+09
# 85                                          20.2             3.367069e+09
# 86                                          20.2             3.367069e+09
# 87                                          20.2             3.367069e+09
# 88                                          20.2             3.367069e+09
# 89                                          20.2             3.367069e+09
# 90                                          20.2             3.367069e+09
# 91                                          20.2             3.367069e+09
# 92                                          20.2             3.367069e+09
# 93                                          20.2             3.367069e+09
# 94                                          20.2             3.367069e+09
# 95                                          20.2             3.367069e+09
# 96                                          20.2             3.367069e+09
# 62                      329732398.0                                    NaN
# 63                      329732398.0                                    NaN
# 64                      329732398.0                                    NaN
# 65                      329732398.0                                    NaN
# 66                      329732398.0                                    NaN
# 67                      329732398.0                                    NaN
# 68                      329732398.0                                    NaN
# 69                      329732398.0                                    NaN
# 70                      329732398.0                                    NaN
# 71                      329732398.0                                    NaN
# 72                      329732398.0                                    NaN
# 73                      329732398.0                                    NaN
# 74                      329732398.0                                    NaN
# 75                      329732398.0                                    NaN
# 76                      329732398.0                                    NaN
# 77                      329732398.0                                    NaN
# 78                      329732398.0                                    NaN
# 79                      329732398.0                                    NaN
# 80                      329732398.0                                    NaN
# 81                      329732398.0                                    NaN
# 82                      329732398.0                                    NaN
# 83                      329732398.0                                    NaN
# 84                      329732398.0                                    NaN
# 85                      329732398.0                                    NaN
# 86                      329732398.0                                    NaN
# 87                      329732398.0                                    NaN
# 88                      329732398.0                                    NaN
# 89                      329732398.0                                    NaN
# 90                      329732398.0                                    NaN
# 91                      329732398.0                                    NaN
# 92                      329732398.0                                    NaN
# 93                      329732398.0                                    NaN
# 94                      329732398.0                                    NaN
# 95                      329732398.0                                    NaN
# 96                      329732398.0                                    NaN
# 97                      329732398.0                                    NaN
# 98                      329732398.0                                    NaN
# 99                      329732398.0                                    NaN
# 100                     329732398.0                                    NaN
# 101                     329732398.0                                    NaN
# 102                     329732398.0                                    NaN
# 103                     329732398.0                                    NaN
# 104                     329732398.0                                    NaN
# 105                     329732398.0                                    NaN
# 106                     329732398.0                                    NaN
# 107                     329732398.0                                    NaN
# 108                     329732398.0                                    NaN
# 109                     329732398.0                                    NaN
# 110                     329732398.0                                    NaN
# 111                     329732398.0                                    NaN
# 112                     329732398.0                                    NaN
# 113                     329732398.0                                    NaN
# 114                     329732398.0                                    NaN
# 115                     329732398.0                                    NaN
# 116                     329732398.0                                    NaN
# 117                     329732398.0                                    NaN
# 118                     329732398.0                                    NaN
# 119                     329732398.0                                    NaN
#
#      Enteric fermentation, CH4 (kg CO2e)  Manure management, CH4 (kg CO2e)  \
# 60                                   NaN                      3.520174e+09
# 61                                   NaN                      3.520174e+09
# 62                                   NaN                      3.520174e+09
# 63                                   NaN                      3.520174e+09
# 64                                   NaN                      3.520174e+09
# 65                                   NaN                      3.520174e+09
# 66                                   NaN                      3.520174e+09
# 67                                   NaN                      3.520174e+09
# 68                                   NaN                      3.520174e+09
# 69                                   NaN                      3.520174e+09
# 70                                   NaN                      3.520174e+09
# 71                                   NaN                      3.520174e+09
# 72                                   NaN                      3.520174e+09
# 73                                   NaN                      3.520174e+09
# 74                                   NaN                      3.520174e+09
# 75                                   NaN                      3.520174e+09
# 76                                   NaN                      3.520174e+09
# 77                                   NaN                      3.520174e+09
# 78                                   NaN                      3.520174e+09
# 79                                   NaN                      3.520174e+09
# 80                                   NaN                      3.520174e+09
# 81                                   NaN                      3.520174e+09
# 82                                   NaN                      3.520174e+09
# 83                                   NaN                      3.520174e+09
# 84                                   NaN                      3.520174e+09
# 85                                   NaN                      3.520174e+09
# 86                                   NaN                      3.520174e+09
# 87                                   NaN                      3.520174e+09
# 99                     1.878925e+09             8.740349e+09  6.725994e+09
# 100                    1.878925e+09             8.740349e+09  6.859314e+09
# 101                    1.878925e+09             8.740349e+09  6.999300e+09
# 102                    1.878925e+09             8.740349e+09  6.932640e+09
# 103                    1.878925e+09             8.740349e+09  7.082625e+09
# 104                    1.878925e+09             8.740349e+09  7.165950e+09
# 105                    1.878925e+09             8.740349e+09  7.182615e+09
# 106                    1.878925e+09             8.740349e+09  7.232610e+09
# 107                    1.878925e+09             8.740349e+09  3.057794e+10
# 108                    1.878925e+09             8.740349e+09  2.904776e+10
# 109                    1.878925e+09             8.740349e+09  2.929240e+10
# 110                    1.878925e+09             8.740349e+09  2.923774e+10
# 111                    1.878925e+09             8.740349e+09  2.876046e+10
# 112                    1.878925e+09             8.740349e+09  2.899810e+10
# 113                    1.878925e+09             8.740349e+09  2.903710e+10
# 114                    1.878925e+09             8.740349e+09  2.951800e+10
# 115                    1.878925e+09             8.740349e+09  2.981300e+10
# 116                    1.878925e+09             8.740349e+09  3.027698e+10
# 117                    1.878925e+09             8.740349e+09  3.069246e+10
# 118                    1.878925e+09             8.740349e+09  3.115768e+10
# 119                    1.878925e+09             8.740349e+09  3.130960e+10
#
# [60 rows x 27 columns]

# %%
# forecasting production value from livestock file
# what would emissions be if trends continue?

# %%
#prophet DF clean
live_prophet = live_emissions[['Animal species', 'Year', 'Final_GHG']]
live_prophet = live_prophet.rename(columns ={'Animal species':'group', 'Year':'ds', 'Final_GHG':'y'})
live_prophet['ds'] = pd.to_datetime(live_prophet['ds'], format='%Y')

display(live_prophet)
# Out:
#       group         ds             y
# 0    Cattle 1961-01-01  5.332294e+11
# 1    Cattle 1962-01-01  5.475238e+11
# 2    Cattle 1963-01-01  5.692124e+11
# 3    Cattle 1964-01-01  5.882520e+11
# 4    Cattle 1965-01-01  5.958619e+11
# ..      ...        ...           ...
# 295   Sheep 2016-01-01  2.654227e+10
# 296   Sheep 2017-01-01  2.642846e+10
# 297   Sheep 2018-01-01  2.647407e+10
# 298   Sheep 2019-01-01  2.631508e+10
# 299   Sheep 2020-01-01  2.604576e+10
#
# [300 rows x 3 columns]

# %%
from prophet import Prophet
# Create a list of unique/distinct livestock
groups = live_emissions['Animal species'].unique()

# Create a separate forecast for each group with iterating over unique zipcode groups
forecasts = []

for group in groups:
    
    # Subset the data for each group
    group_data = live_prophet[live_prophet['group'] == group]

    # Create Prophet model
    model = Prophet()
    model.fit(group_data)

    # Precdict forecast for the next 10 Years
    future = model.make_future_dataframe(periods=10, freq='Y')
    forecast = model.predict(future)

    # Add the group value column to the forecast DataFrame
    forecast['group'] = group

    # Append the forecast to the list of forecasts
    forecasts.append(forecast)
    
    #print unaltered axis of each forecast as part of the for-loop
    model.plot(forecast)
    plt.legend([group,'forecast', 'uncertainty'],loc='upper left')
    
    #print second copy of each forecast with normalized axis
    model.plot(forecast)
    plt.ylim([1e9, 8e11])
    plt.legend([group,'forecast', 'uncertainty'],loc='upper left')

# Combine the forecasts for all groups into a single DataFrame
combined_forecast = pd.concat(forecasts)

# display(combined_forecast)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/viysh3q_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/ii2n14we.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40526', 'data', 'file=/tmp/tmpaaj1z48y/viysh3q_.json', 'init=/tmp/tmpaaj1z48y/ii2n14we.json', 'output', 'file=/tmp/tmpaaj1z48y/prophet_model45xtf9sx/prophet_model-20230327002958.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:29:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:29:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/_9bnqvvv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/_ad2kjom.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5626', 'data', 'file=/tmp/tmpaaj1z48y/_9bnqvvv.json', 'init=/tmp/tmpaaj1z48y/_ad2kjom.json', 'output', 'file=/tmp/tmpaaj1z48y/prophet_modelskktklcp/prophet_model-20230327002959.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:29:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:30:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/fx1a_m2n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/6eij_2b6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62800', 'data', 'file=/tmp/tmpaaj1z48y/fx1a_m2n.json', 'init=/tmp/tmpaaj1z48y/6eij_2b6.json', 'output', 'file=/tmp/tmpaaj1z48y/prophet_modelj37u_rrp/prophet_model-20230327003001.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:30:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:30:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/gr1v02xm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/olkj061p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41867', 'data', 'file=/tmp/tmpaaj1z48y/gr1v02xm.json', 'init=/tmp/tmpaaj1z48y/olkj061p.json', 'output', 'file=/tmp/tmpaaj1z48y/prophet_modellz0rlz3r/prophet_model-20230327003001.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:30:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:30:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/4wjgz6n0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpaaj1z48y/23cxernd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99259', 'data', 'file=/tmp/tmpaaj1z48y/4wjgz6n0.json', 'init=/tmp/tmpaaj1z48y/23cxernd.json', 'output', 'file=/tmp/tmpaaj1z48y/prophet_modela9lvj1kp/prophet_model-20230327003002.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:30:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:30:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
combined_forecast
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  1961-01-01  5.506357e+10  5.298794e+11  5.817767e+11  5.506357e+10
# 1  1962-01-01  6.261117e+10  5.375262e+11  5.903568e+11  6.261117e+10
# 2  1963-01-01  7.015876e+10  5.456523e+11  6.000558e+11  7.015876e+10
# 3  1964-01-01  7.770635e+10  5.547041e+11  6.063003e+11  7.770635e+10
# 4  1965-01-01  8.527462e+10  5.600118e+11  6.116907e+11  8.527462e+10
# ..        ...           ...           ...           ...           ...
# 65 2025-12-31 -1.185414e+11  1.665565e+10  2.407683e+10 -1.201388e+11
# 66 2026-12-31 -1.189691e+11  1.498247e+10  2.291944e+10 -1.209830e+11
# 67 2027-12-31 -1.193969e+11  1.314140e+10  2.165643e+10 -1.218524e+11
# 68 2028-12-31 -1.198258e+11  1.523056e+10  2.431716e+10 -1.226883e+11
# 69 2029-12-31 -1.202536e+11  1.334632e+10  2.349445e+10 -1.236910e+11
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0   5.506357e+10    5.004451e+11          5.004451e+11          5.004451e+11
# 1   6.261117e+10    5.010356e+11          5.010356e+11          5.010356e+11
# 2   7.015876e+10    5.021280e+11          5.021280e+11          5.021280e+11
# 3   7.770635e+10    5.037208e+11          5.037208e+11          5.037208e+11
# 4   8.527462e+10    5.004451e+11          5.004451e+11          5.004451e+11
# ..           ...             ...                   ...                   ...
# 65 -1.168969e+11    1.388733e+11          1.388733e+11          1.388733e+11
# 66 -1.169049e+11    1.379090e+11          1.379090e+11          1.379090e+11
# 67 -1.169163e+11    1.367276e+11          1.367276e+11          1.367276e+11
# 68 -1.167555e+11    1.396187e+11          1.396187e+11          1.396187e+11
# 69 -1.166082e+11    1.388733e+11          1.388733e+11          1.388733e+11
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   5.004451e+11  5.004451e+11  5.004451e+11                   0.0
# 1   5.010356e+11  5.010356e+11  5.010356e+11                   0.0
# 2   5.021280e+11  5.021280e+11  5.021280e+11                   0.0
# 3   5.037208e+11  5.037208e+11  5.037208e+11                   0.0
# 4   5.004451e+11  5.004451e+11  5.004451e+11                   0.0
# ..           ...           ...           ...                   ...
# 65  1.388733e+11  1.388733e+11  1.388733e+11                   0.0
# 66  1.379090e+11  1.379090e+11  1.379090e+11                   0.0
# 67  1.367276e+11  1.367276e+11  1.367276e+11                   0.0
# 68  1.396187e+11  1.396187e+11  1.396187e+11                   0.0
# 69  1.388733e+11  1.388733e+11  1.388733e+11                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper          yhat  \
# 0                          0.0                         0.0  5.555087e+11
# 1                          0.0                         0.0  5.636467e+11
# 2                          0.0                         0.0  5.722868e+11
# 3                          0.0                         0.0  5.814272e+11
# 4                          0.0                         0.0  5.857197e+11
# ..                         ...                         ...           ...
# 65                         0.0                         0.0  2.033193e+10
# 66                         0.0                         0.0  1.893985e+10
# 67                         0.0                         0.0  1.733067e+10
# 68                         0.0                         0.0  1.979285e+10
# 69                         0.0                         0.0  1.861971e+10
#
#      group
# 0   Cattle
# 1   Cattle
# 2   Cattle
# 3   Cattle
# 4   Cattle
# ..     ...
# 65   Sheep
# 66   Sheep
# 67   Sheep
# 68   Sheep
# 69   Sheep
#
# [350 rows x 17 columns]

# %%
model.plot(combined_forecast)
plt.legend()

# %%
from prophet import Prophet
import matplotlib.pyplot as plt
import pandas as pd
import datetime

df_cattle = pd.read_csv('Cattle.csv')
df_cattle['Year'] = pd.to_datetime(df_cattle['Year'], format='%Y')
df_cattle = df_cattle.rename(columns={'Value': 'y'})
df_cattle = df_cattle.rename(columns={'Year': 'ds'})

#df_cattle

model = Prophet()
model.fit(df_cattle)

future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)

model.plot(forecast)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-4403756681b0> in <module>
#       4 import datetime
#       5
# ----> 6 df_cattle = pd.read_csv('Cattle.csv')
#       7 df_cattle['Year'] = pd.to_datetime(df_cattle['Year'], format='%Y')
#       8 df_cattle = df_cattle.rename(columns={'Value': 'y'})
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cattle.csv'

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='730 days', period='180 days', horizon='365 days')

# %%
from sklearn.metrics import mean_absolute_percentage_error
#mape = mean_absolute_percentage_error(df_cattle['y'], forecast['yhat'])
#print(f"MAPE: {mape}")

# %%
df_ghg = pd.read_csv('https://raw.githubusercontent.com/garyhchenjobs/IST718-Group_Final/main/ghg-emissions.csv')
df_ghg = df_ghg.set_index('Country/Region').transpose()
df_ghg = df_ghg.tail(-1)
df_ghg.head()
df_ghg.describe()
df_ghg.dtypes

# %%
df_ghg.plot()

# %%
df_crop = pd.read_csv('crop1.csv')
df_crop_production = df_crop[df_crop.Element == 'Production']
df_crop_production.to_csv('crop_production.csv')
